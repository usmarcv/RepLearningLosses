# %%
import torch
# import networks.vit as vits

# %%
pretrained_weights = '/home/lobo/github/RepLearningLosses/save/DINOv1/dino_deitsmall8_pretrain_full_checkpoint.pth'

state_dict = torch.load(pretrained_weights, map_location="cpu", weights_only=False)

# %%
state_dict
# Out:
# {'student': {'module.backbone.cls_token': tensor([[[-0.0044,  0.0040,  0.0218, -0.0034, -0.0599, -0.0478,  0.0021,
#              0.0299, -0.0014,  0.0063, -0.0088, -0.0781, -0.0042,  0.0013,
#              0.0023, -0.0244,  0.0377,  0.0015,  0.0085,  0.0444,  0.0014,
#              0.0002, -0.0010,  0.0020, -0.0176,  0.0044,  0.0020, -0.0016,
#              0.0012,  0.0188,  0.0020,  0.0250,  0.0024,  0.0015, -0.0019,
#             -0.0022, -0.0017,  0.0385,  0.0021,  0.0175, -0.0131,  0.0293,
#              0.0017, -0.0026, -0.0061, -0.0098, -0.0251, -0.0318,  0.0013,
#             -0.0044,  0.0016,  0.0294,  0.0021, -0.0104,  0.0008,  0.0213,
#             -0.0112,  0.0268,  0.0286, -0.0270, -0.0093, -0.0079,  0.0309,
#             -0.0031, -0.0157,  0.0521, -0.0009,  0.0293,  0.0007, -0.0088,
#             -0.0044,  0.0015, -0.0022,  0.0200, -0.0009,  0.0031, -0.0290,
#             -0.0008,  0.0048,  0.0024, -0.0193,  0.0325, -0.0087,  0.0027,
# ...

# %%
# checkpoint_key = 'student'
# if checkpoint_key is not None and checkpoint_key in state_dict:
#     print(f"Take key {checkpoint_key} in provided checkpoint dict")
#     state_dict = state_dict[checkpoint_key]
# Out:
# Take key student in provided checkpoint dict

# %%
for key in state_dict.keys():
    print(key)
# Out:
# student
# teacher
# early_stopping_epoch

# %%
for key, value in state_dict.items():
    print(f"{key}: {value}")
# Out:
# student: {'module.backbone.cls_token': tensor([[[-0.0044,  0.0040,  0.0218, -0.0034, -0.0599, -0.0478,  0.0021,
#            0.0299, -0.0014,  0.0063, -0.0088, -0.0781, -0.0042,  0.0013,
#            0.0023, -0.0244,  0.0377,  0.0015,  0.0085,  0.0444,  0.0014,
#            0.0002, -0.0010,  0.0020, -0.0176,  0.0044,  0.0020, -0.0016,
#            0.0012,  0.0188,  0.0020,  0.0250,  0.0024,  0.0015, -0.0019,
#           -0.0022, -0.0017,  0.0385,  0.0021,  0.0175, -0.0131,  0.0293,
#            0.0017, -0.0026, -0.0061, -0.0098, -0.0251, -0.0318,  0.0013,
#           -0.0044,  0.0016,  0.0294,  0.0021, -0.0104,  0.0008,  0.0213,
#           -0.0112,  0.0268,  0.0286, -0.0270, -0.0093, -0.0079,  0.0309,
#           -0.0031, -0.0157,  0.0521, -0.0009,  0.0293,  0.0007, -0.0088,
#           -0.0044,  0.0015, -0.0022,  0.0200, -0.0009,  0.0031, -0.0290,
#           -0.0008,  0.0048,  0.0024, -0.0193,  0.0325, -0.0087,  0.0027,
# ...

# %%
# model = vits.vit_small()

# # remove `module.` prefix
# state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}

# # remove `backbone.` prefix induced by multicrop wrapper
# state_dict = {k.replace("backbone.", ""): v for k, v in state_dict.items()}
# msg = model.load_state_dict(state_dict, strict=False)

# print('Pretrained weights found at {} and loaded with msg: {}'.format(pretrained_weights, msg))
# Out:
# Pretrained weights found at /home/lobo/github/RepLearningLosses/save/DINOv1/checkpoint0040.pth and loaded with msg: _IncompatibleKeys(missing_keys=[], unexpected_keys=['head.mlp.0.weight', 'head.mlp.0.bias', 'head.mlp.2.weight', 'head.mlp.2.bias', 'head.mlp.4.weight', 'head.mlp.4.bias', 'head.last_layer.weight_g', 'head.last_layer.weight_v'])

# %% [markdown]
# ## Testing pretrained models

# %%
#Testando o modelo pre-treinado
import torch
dinov2_vits14 = torch.hub.load('facebookresearch/dinov2', 'dinov2_vits14')
# Out:
# Using cache found in /home/lobo/.cache/torch/hub/facebookresearch_dinov2_main
# /home/lobo/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /home/lobo/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /home/lobo/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")

# %%
# dinov2_vits14.state_dict().items()
# Out:
# odict_items([('cls_token', tensor([[[-6.8410e-03,  2.6086e-03,  1.6149e-02, -2.5937e-03, -1.6370e-03,
#           -2.3220e-03,  2.0959e-04, -8.5568e-04,  2.7370e-03,  3.4901e-03,
#           -4.6377e-03, -1.0370e-02, -7.4891e-04, -1.3678e-02, -4.3106e-03,
#           -2.9372e-03, -1.2939e-03,  3.0098e-03, -3.4187e-02,  2.2269e-03,
#           -6.4373e-03,  3.5713e-02,  6.9370e-03,  2.7280e-04,  3.2431e-03,
#            2.6636e-02, -3.0152e-04, -6.1275e-04, -2.3360e-03, -1.9538e-02,
#           -3.0734e-03,  3.4016e-04,  3.1648e-03,  1.9603e-03,  3.9863e-03,
#            4.8807e-03,  1.2272e-03,  1.2598e-03,  4.4603e-03, -3.4178e-04,
#            2.7807e-03, -2.1892e-02,  1.6567e-03, -8.4406e-03,  4.7966e-03,
#           -1.7167e-04, -4.3230e-03, -5.8655e-04,  1.6425e-03,  1.9382e-02,
#           -2.6624e-03, -6.7002e-04,  1.7988e-03,  2.5716e-03, -1.8315e-03,
#            1.2139e-02,  2.5226e-03, -1.1061e-04,  4.1116e-03, -3.5940e-03,
# ...
